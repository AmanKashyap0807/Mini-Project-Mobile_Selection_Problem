# %% [markdown]
# <a href="https://colab.research.google.com/github/AmanKashyap0807/Mini-Project-Mobile_Selection_Problem/blob/main/Demo_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Mobile selection** **problem**
#
# This is a basic MCDM code for selecting best mobile according to given list of mobile data and preference
#
#
#
# ---
#
# Change Runtime type to R programming

# %% [markdown]
# Installing and Importing Topsis

# %%
install.packages("topsis")
library(topsis)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %% [markdown]
# Here the given dataset (https://www.kaggle.com/datasets/artempozdniakov/ukrainian-market-mobile-phones-data) is from kaggle
#
# Download and save in a data frame

# %%
dataSet<-read.csv("/content/phones_data.csv")
head(dataSet)
# Out:
#   X brand_name model_name                                   os      popularity
# 1 0 ALCATEL    1 1/8GB Bluish Black (5033D-2JALUAA)         Android  422
# 2 1 ALCATEL    1 5033D 1/16GB Volcano Black (5033D-2LALUAF) Android  323
# 3 2 ALCATEL    1 5033D 1/16GB Volcano Black (5033D-2LALUAF) Android  299
# 4 3 ALCATEL    1 5033D 1/16GB Volcano Black (5033D-2LALUAF) Android  287
# 5 4 Nokia      1.3 1/16GB Charcoal                          Android 1047
# 6 5 Honor      10 6/64GB Black                              Android   71
#   best_price lowest_price highest_price sellers_amount screen_size memory_size
# 1  1690       1529         1819         36             5.00         8
# 2  1803       1659         2489         36             5.00        16
# 3  1803       1659         2489         36             5.00        16
# 4  1803       1659         2489         36             5.00        16
# 5  1999         NA           NA         10             5.71        16
# ...

# %% [markdown]
# Removing all the not useful colums and also rows which has incomplete data

# %%
dataSet <- dataSet[, -which(names(dataSet) == "X")]
dataSet <- dataSet[, -which(names(dataSet) == "brand_name")]
dataSet <- dataSet[, -which(names(dataSet) == "os")]
dataSet <- dataSet[, -which(names(dataSet) == "release_date")]
dataSet <- dataSet[, -which(names(dataSet) == "lowest_price")]
dataSet <- dataSet[, -which(names(dataSet) == "highest_price")]
dataSet <- dataSet[, -which(names(dataSet) == "sellers_amount")]
dataSet<-na.omit(dataSet)
dataSet
# Out:
#      model_name                                   popularity best_price
# 1    1 1/8GB Bluish Black (5033D-2JALUAA)          422        1690
# 2    1 5033D 1/16GB Volcano Black (5033D-2LALUAF)  323        1803
# 3    1 5033D 1/16GB Volcano Black (5033D-2LALUAF)  299        1803
# 4    1 5033D 1/16GB Volcano Black (5033D-2LALUAF)  287        1803
# 5    1.3 1/16GB Charcoal                          1047        1999
# 6    10 6/64GB Black                                71       10865
# 7    10 Lite 3/32GB Blue                           424        3999
# 8    10 Lite 4/64GB Black                          134        4973
# 9    10 lite 3/128GB Blue                          477        5100
# 10   10 lite 3/64GB Black                          215        4948
# 11   10 lite 3/64GB Black                          179        4948
# 12   10 lite 3/64GB Blue                           437        5165
# 13   105 DS 2019 Pink (16KIGP01A01)                 18         583
# ...

# %%
dataSet$model_name<-NULL
head(dataSet)
# Out:
#   popularity best_price screen_size memory_size battery_size
# 1  422        1690      5.00         8          2000
# 2  323        1803      5.00        16          2000
# 3  299        1803      5.00        16          2000
# 4  287        1803      5.00        16          2000
# 5 1047        1999      5.71        16          3000
# 6   71       10865      5.80        64          3400

# %% [markdown]
# Letting the weights and impacts

# %%
weight<-c(2,2,1,2,2)
impact<-c('+','-','+','+','+')
topsisRank<-topsis(as.matrix(finalData), weight,impact)
topsisRank
# Out:
#     alt.row score     rank
# 1    1      0.3682661 598
# 2    2      0.3678979 606
# 3    3      0.3675528 609
# 4    4      0.3673837 611
# 5    5      0.3406121 773
# 6    6      0.3696781 576
# 7    7      0.3925278 256
# 8    8      0.3708934 552
# 9    9      0.3703893 561
# 10  10      0.3735192 518
# 11  11      0.3607046 703
# 12  12      0.3671415 612
# 13  13      0.3659167 630
# 14  14      0.3658372 632
# 15  15      0.3654509 642
# 16  16      0.3661357 627
# 17  17      0.3656014 637
# 18  18      0.3654882 640
# 19  19      0.4020548 135
# 20  20      0.3877493 302
# 21  21      0.3920975 260
# 22  22      0.3965298 202
# 23  23      0.3743029 509
# 24  24      0.3751019 497
# 25  25      0.3810316 385
# 26  26      0.4080574 105
# 27  27      0.4081256 102
# 28  28      0.3932292 246
# 29  29      0.3648580 649
# 30  30      0.3573434 719
# ⋮   ⋮       ⋮         ⋮
# 823 823     0.3439889 763
# 824 824     0.3645131 655
# 825 825     0.3567726 723
# ...

# %% [markdown]
# Merging the topsis rank with the intial dataset

# %%
intialData<-read.csv("/content/phones_data.csv")
intialData_wona<-na.omit(intialData)
finaldf<-cbind(intialData_wona,topsisRank)
finaldf
# Out:
#      X    brand_name model_name                                   os
# 1     0   ALCATEL    1 1/8GB Bluish Black (5033D-2JALUAA)         Android
# 2     1   ALCATEL    1 5033D 1/16GB Volcano Black (5033D-2LALUAF) Android
# 3     2   ALCATEL    1 5033D 1/16GB Volcano Black (5033D-2LALUAF) Android
# 4     3   ALCATEL    1 5033D 1/16GB Volcano Black (5033D-2LALUAF) Android
# 6     5   Honor      10 6/64GB Black                              Android
# 8     7   Honor      10 Lite 4/64GB Black                         Android
# 9     8   Honor      10 lite 3/128GB Blue                         Android
# 10    9   Honor      10 lite 3/64GB Black                         Android
# 11   10   Honor      10 lite 3/64GB Black                         Android
# 12   11   Honor      10 lite 3/64GB Blue                          Android
# 13   12   Nokia      105 DS 2019 Pink (16KIGP01A01)
# 16   15   Nokia      105 Dual Sim New Black (A00028315)
# ...

# %%
library(dplyr)
result<-finaldf %>% filter(rank==1)
result
# Out:
#   X   brand_name model_name                                     os
# 1 482 Samsung    Galaxy S10+ SM-G975 DS 1TB Black (SM-G975FCKH) Android
#   popularity best_price lowest_price highest_price sellers_amount screen_size
# 1 847        22932      20995        47292         22             6.4
#   memory_size battery_size release_date alt.row score     rank
# 1 1000        4000         2-2019       330     0.7164058 1

# %%
result<-final %>% filter(rank==1)
result
# Out:
#   X   brand_name model_name                                     os
# 1 482 Samsung    Galaxy S10+ SM-G975 DS 1TB Black (SM-G975FCKH) Android
#   popularity best_price lowest_price highest_price sellers_amount screen_size
# 1 847        22932      20995        47292         22             6.4
#   memory_size battery_size release_date alt.row score     rank
# 1 1000        4000         2-2019       330     0.7164058 1
